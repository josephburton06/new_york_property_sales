# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn import tree

import seaborn as sns

import acquire_prep
from acquire_prep import acquire_df
from acquire_prep import prep_df

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df, no_sqft_df = prep_df()

# %%
df.shape
# Out:
# (37047, 21)

# %%
no_sqft_df.shape
# Out:
# (21557, 21)

# %%
df.head().T
# Out:
#                                                                           0  \
# borough                                                                   1
# neighborhood                                                  ALPHABET CITY
# building_class_category         07 RENTALS - WALKUP APARTMENTS
# tax_class_at_present                                                     2A
# block                                                                   392
# lot                                                                       6
# ease_ment
# building_class_at_present                                                C2
# address                                                        153 AVENUE B
# apartment_number
# zip_code                                                              10009
# residential_units                                                         5
# commercial_units                                                          0
# total_units                                                               5
# land_square_feet                                                       1633
# gross_square_feet                                                      6440
# year_built                                                             1900
# tax_class_at_time_of_sale                                                 2
# building_class_at_time_of_sale                                           C2
# sale_price                                                          6625000
# sale_date                                               2017-07-19 00:00:00
#
#                                                                           3  \
# borough                                                                   1
# neighborhood                                                  ALPHABET CITY
# building_class_category         07 RENTALS - WALKUP APARTMENTS
# tax_class_at_present                                                     2B
# block                                                                   402
# lot                                                                      21
# ease_ment
# building_class_at_present                                                C4
# address                                                 154 EAST 7TH STREET
# apartment_number
# zip_code                                                              10009
# residential_units                                                        10
# commercial_units                                                          0
# total_units                                                              10
# land_square_feet                                                       2272
# gross_square_feet                                                      6794
# year_built                                                             1913
# tax_class_at_time_of_sale                                                 2
# building_class_at_time_of_sale                                           C4
# sale_price                                                          3936272
# sale_date                                               2016-09-23 00:00:00
#
#                                                                           4  \
# borough                                                                   1
# neighborhood                                                  ALPHABET CITY
# building_class_category         07 RENTALS - WALKUP APARTMENTS
# tax_class_at_present                                                     2A
# block                                                                   404
# lot                                                                      55
# ease_ment
# building_class_at_present                                                C2
# address                                              301 EAST 10TH   STREET
# apartment_number
# zip_code                                                              10009
# residential_units                                                         6
# commercial_units                                                          0
# total_units                                                               6
# land_square_feet                                                       2369
# gross_square_feet                                                      4615
# year_built                                                             1900
# tax_class_at_time_of_sale                                                 2
# building_class_at_time_of_sale                                           C2
# sale_price                                                          8000000
# sale_date                                               2016-11-17 00:00:00
#
#                                                                           6  \
# borough                                                                   1
# neighborhood                                                  ALPHABET CITY
# building_class_category         07 RENTALS - WALKUP APARTMENTS
# tax_class_at_present                                                     2B
# block                                                                   406
# lot                                                                      32
# ease_ment
# building_class_at_present                                                C4
# address                                                        210 AVENUE B
# apartment_number
# zip_code                                                              10009
# residential_units                                                         8
# commercial_units                                                          0
# total_units                                                               8
# land_square_feet                                                       1750
# gross_square_feet                                                      4226
# year_built                                                             1920
# tax_class_at_time_of_sale                                                 2
# building_class_at_time_of_sale                                           C4
# sale_price                                                          3192840
# sale_date                                               2016-09-23 00:00:00
#
#                                                                           9
# borough                                                                   1
# neighborhood                                                  ALPHABET CITY
# building_class_category         08 RENTALS - ELEVATOR APARTMENTS
# tax_class_at_present                                                      2
# block                                                                   387
# lot                                                                     153
# ease_ment
# building_class_at_present                                                D9
# address                                                 629 EAST 5TH STREET
# apartment_number
# zip_code                                                              10009
# residential_units                                                        24
# commercial_units                                                          0
# total_units                                                              24
# land_square_feet                                                       4489
# gross_square_feet                                                     18523
# year_built                                                             1920
# tax_class_at_time_of_sale                                                 2
# building_class_at_time_of_sale                                           D9
# sale_price                                                         16232000
# sale_date                                               2016-11-07 00:00:00

# %%
df.isnull().sum()
# Out:
# borough                           0
# neighborhood                      0
# building_class_category           0
# tax_class_at_present              0
# block                             0
# lot                               0
# ease_ment                         0
# building_class_at_present         0
# address                           0
# apartment_number                  0
# zip_code                          0
# residential_units                 0
# commercial_units                  0
# total_units                       0
# land_square_feet                  0
# gross_square_feet                 0
# year_built                        0
# tax_class_at_time_of_sale         0
# building_class_at_time_of_sale    0
# sale_price                        0
# sale_date                         0
# dtype: int64

# %%
df.head().T
# Out:
#                                                                           0  \
# borough                                                                   1
# neighborhood                                                  ALPHABET CITY
# building_class_category         07 RENTALS - WALKUP APARTMENTS
# tax_class_at_present                                                     2A
# block                                                                   392
# lot                                                                       6
# ease_ment
# building_class_at_present                                                C2
# address                                                        153 AVENUE B
# apartment_number
# zip_code                                                              10009
# residential_units                                                         5
# commercial_units                                                          0
# total_units                                                               5
# land_square_feet                                                       1633
# gross_square_feet                                                      6440
# year_built                                                             1900
# tax_class_at_time_of_sale                                                 2
# building_class_at_time_of_sale                                           C2
# sale_price                                                          6625000
# sale_date                                               2017-07-19 00:00:00
#
#                                                                           3  \
# borough                                                                   1
# neighborhood                                                  ALPHABET CITY
# building_class_category         07 RENTALS - WALKUP APARTMENTS
# tax_class_at_present                                                     2B
# block                                                                   402
# lot                                                                      21
# ease_ment
# building_class_at_present                                                C4
# address                                                 154 EAST 7TH STREET
# apartment_number
# zip_code                                                              10009
# residential_units                                                        10
# commercial_units                                                          0
# total_units                                                              10
# land_square_feet                                                       2272
# gross_square_feet                                                      6794
# year_built                                                             1913
# tax_class_at_time_of_sale                                                 2
# building_class_at_time_of_sale                                           C4
# sale_price                                                          3936272
# sale_date                                               2016-09-23 00:00:00
#
#                                                                           4  \
# borough                                                                   1
# neighborhood                                                  ALPHABET CITY
# building_class_category         07 RENTALS - WALKUP APARTMENTS
# tax_class_at_present                                                     2A
# block                                                                   404
# lot                                                                      55
# ease_ment
# building_class_at_present                                                C2
# address                                              301 EAST 10TH   STREET
# apartment_number
# zip_code                                                              10009
# residential_units                                                         6
# commercial_units                                                          0
# total_units                                                               6
# land_square_feet                                                       2369
# gross_square_feet                                                      4615
# year_built                                                             1900
# tax_class_at_time_of_sale                                                 2
# building_class_at_time_of_sale                                           C2
# sale_price                                                          8000000
# sale_date                                               2016-11-17 00:00:00
#
#                                                                           6  \
# borough                                                                   1
# neighborhood                                                  ALPHABET CITY
# building_class_category         07 RENTALS - WALKUP APARTMENTS
# tax_class_at_present                                                     2B
# block                                                                   406
# lot                                                                      32
# ease_ment
# building_class_at_present                                                C4
# address                                                        210 AVENUE B
# apartment_number
# zip_code                                                              10009
# residential_units                                                         8
# commercial_units                                                          0
# total_units                                                               8
# land_square_feet                                                       1750
# gross_square_feet                                                      4226
# year_built                                                             1920
# tax_class_at_time_of_sale                                                 2
# building_class_at_time_of_sale                                           C4
# sale_price                                                          3192840
# sale_date                                               2016-09-23 00:00:00
#
#                                                                           9
# borough                                                                   1
# neighborhood                                                  ALPHABET CITY
# building_class_category         08 RENTALS - ELEVATOR APARTMENTS
# tax_class_at_present                                                      2
# block                                                                   387
# lot                                                                     153
# ease_ment
# building_class_at_present                                                D9
# address                                                 629 EAST 5TH STREET
# apartment_number
# zip_code                                                              10009
# residential_units                                                        24
# commercial_units                                                          0
# total_units                                                              24
# land_square_feet                                                       4489
# gross_square_feet                                                     18523
# year_built                                                             1920
# tax_class_at_time_of_sale                                                 2
# building_class_at_time_of_sale                                           D9
# sale_price                                                         16232000
# sale_date                                               2016-11-07 00:00:00

# %% [markdown]
# ### We may need to consider a separate dataframe with rows that do not have sq. ft.

# %%
df.gross_square_feet = pd.to_numeric(df.gross_square_feet, downcast='integer')

# %%
df.dtypes
# Out:
# borough                            int64
# neighborhood                      object
# building_class_category           object
# tax_class_at_present              object
# block                              int64
# lot                                int64
# ease_ment                         object
# building_class_at_present         object
# address                           object
# apartment_number                  object
# zip_code                           int64
# residential_units                  int64
# commercial_units                   int64
# total_units                        int64
# land_square_feet                  object
# gross_square_feet                  int32
# year_built                         int64
# tax_class_at_time_of_sale          int64
# building_class_at_time_of_sale    object
# sale_price                         int64
# sale_date                         object
# dtype: object

# %%
df.describe()
# Out:
#             borough         block           lot      zip_code  \
# count  37047.000000  37047.000000  37047.000000  37047.000000
# mean       3.370880   5124.861959    223.823387  10941.205064
# std        0.962703   3633.065312    476.778567   1005.914629
# min        1.000000      1.000000      1.000000      0.000000
# 25%        3.000000   2135.000000     21.000000  10466.000000
# 50%        3.000000   4666.000000     44.000000  11217.000000
# 75%        4.000000   7273.000000     94.000000  11358.000000
# max        5.000000  16319.000000   7501.000000  11694.000000
#
#        residential_units  commercial_units   total_units  gross_square_feet  \
# count       37047.000000      37047.000000  37047.000000       3.704700e+04
# mean            2.459308          0.258024      2.723162       3.526989e+03
# std            17.764163         12.472264     21.831420       2.993774e+04
# min             0.000000          0.000000      0.000000       0.000000e+00
# 25%             1.000000          0.000000      1.000000       8.680000e+02
# 50%             1.000000          0.000000      1.000000       1.550000e+03
# 75%             2.000000          0.000000      2.000000       2.340000e+03
# max          1844.000000       2261.000000   2261.000000       3.750565e+06
#
#          year_built  tax_class_at_time_of_sale    sale_price
# count  37047.000000               37047.000000  3.704700e+04
# mean    1853.820660                   1.411963  1.504957e+06
# std      414.852672                   0.740624  1.527981e+07
# min        0.000000                   1.000000  1.110000e+03
# 25%     1920.000000                   1.000000  4.000000e+05
# 50%     1931.000000                   1.000000  6.189000e+05
# 75%     1962.000000                   2.000000  9.600000e+05
# max     2017.000000                   4.000000  2.210000e+09

# %% [markdown]
# ### Why are there zipcodes with 0?  Why is there a 0 in year built?
